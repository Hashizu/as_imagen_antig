# %% [markdown]
# # 08. より描画内容を限定する
#
# ## 概要
# 特定のワードに対して、売れそうな～を生成しても、既存のアイデアの中で収まりがち。
# ある程度オリジナリティのあるアイデアに対して、細部や描画・表現方法に多様性を持たせたい。

# %%
import util
# KEYWORD = "卒業式のコンセプトアート。無地の背景に、木製の丸い頭を持つおもちゃの人間を中心とした3Dレンダリング。おもちゃの建物。"
# TAGWORDS = ["卒業", "春", "入学", "新学期", "学校", "別れ", "成長"]
# KEYWORD = "株価のチャート"
# TAGWORDS = ["株","株価","仮想通貨", "取引所", "安全", "安心", "投資", "ポートフォリオ", "資産", "ビットコイン"]
# KEYWORD = "賛成"
# TAGWORDS = ["賛成", "議論", "反対", "賛否両論", "検討", "議論", "政治", "投票"]
# KEYWORD = "ホログラフィックディスプレイのある近未来的な研究室。大きなフラスコから小さなフラスコへの蒸留のイメージ"
# TAGWORDS = ["AI", "人工知能", "生成AI", "近未来", "ホログラム", "強化学習", "教師あり学習", "蒸留", "学習","スパコン", "スーパーコンピューター", "研究室"]

#職業、トリマーなど、コーヒー豆、料理、カシューナッツ
# KEYWORD = "A detailed cross-section of an iceberg showcases the 'tip of the iceberg' idiom, with a small, jagged portion visible above the dark blue water. The submerged section of the iceberg is colossal and menacing, shaped like a skull with its fractured surface hinting at its fragility and instability. The ominous lighting casts a sense of foreboding, emphasizing the hidden danger lurking beneath the surface. Jagged edges and sharp protrusions cover the iceberg's exterior, adding to the sense of a looming threat. The surrounding water is turbulent and dark, with ominous shadows swirling beneath the surface. The visible tip of the iceberg, resembling a skull's forehead, emphasizes the concept of a much larger, concealed problem. The skull-like structure and its empty, hollow eyes create a sinister and dangerous atmosphere, underscoring the hidden threat and impending doom concealed beneath the water's surface."
# TAGWORDS = ["氷山の一角", "ことわざ", "氷河", "idiom", "調査", "統計", "ビジネス", "標本", "分析", "問題", "政治", "社会", "社会問題", "地球", "地球温暖化"]
KEYWORD = "パンドラの箱が開き、封印されていた災いが抑えきれなくなり解放される"
TAGWORDS = ["パンドラの箱を開ける", "パンドラの箱", "パンドラ", "ことわざ", "idiom", "調査", "統計", "ビジネス", "分析", "慣習", "問題", "政治", "社会", "社会問題","封印", "災い"]

# KEYWORD = "AIを、チェーン等で封印、禁止する比喩"
# TAGWORDS = ["AI", "生成AI", "禁止","規制", "法律", "入試", "テスト", "勉強", "塾", "代行", "イラスト", "倫理", "ELSI", "SDGs", "ディストピア"]

# KEYWORD = "握手をしている手のクローズアップ"
# TAGWORDS = ["ビジネス", "握手", "合意", "パートナーシップ", "信頼", "成功", "ビジネスマン", 
#     "ビジネスパーソン", "スーツ", "オフィス街", "都市", "ビル", "高層ビル", "未来", 
#     "協力", "チームワーク", "取引", "契約", "金融", "企業", "会社", "組織", 
#     "グローバル", "国際", "投資", "成長", "発展", "戦略", "リーダーシップ", 
#     "交渉", "男性", "女性", "多様性"]

# KEYWORD = "生成AIに学習のアドバイスをもらう大学生"
# TAGWORDS = ["AI", "生成AI", "相談", "カウンセリング", "質問", "解決", "ロボット", "バディ", "入試", "テスト", "勉強", "塾", "代行","AIバディ","禁止",]

# KEYWORD = "早起きは三文の徳"
# TAGWORDS = ["ことわざ","idiom", "早起きは三文の徳", "The early bird catches the worm", "生活習慣", "生活", "習慣", "ヨガ", "朝活", "ジム", "健康", "運動", "勉強","早起き", "朝日"]

# KEYWORD = "スーツの男性が両手で名刺を持ち丁寧に名刺を差し出している。首から下のクローズアップ。スタイルは日本のモダンなデジタルアートやポリグラフィックなど。"
# TAGWORDS = ["ビジネス", "挨拶", "マナー", "パートナー", "成功", "解決", "スーツ", "オフィシャル", "名刺", "名刺交換", "社会人", "オフィス"]

KEYWORD = "あごに手をあて考える夫婦"
TAGWORDS = ["子育て", "疑問", "夫婦", "家族", "保険", "金融", "クレジットカード", "質問", "悩み", "FAQ", "解決"]

gen = util.generate_image_for_as(KEYWORD=KEYWORD, TAGWORDS=TAGWORDS, N_IDEA=3,)
df_prompt = gen.make_prompt_from_seed(image_style="japanese_simple",)
gen.auto_gen_and_upscale(df_prompt)
# Out:
# make prompt : japanese_simple
# Get English prompt
# Get tags
# c:\Users\athen\Desktop\works\adobestock\code\sketch_seed\output\2025-07-21T12-40_悩んでいたり、疑問を持つ夫婦 フォルダを作成しました。
# 画像を保存しました: c:\Users\athen\Desktop\works\adobestock\code\sketch_seed\output\2025-07-21T12-40_悩んでいたり、疑問を持つ夫婦\000_手描き線画で表現された夫婦の悩みを抱える家計管理の瞬間が伝わるミニマルイラスト.png
# 画像を保存しました: c:\Users\athen\Desktop\works\adobestock\code\sketch_seed\output\2025-07-21T12-40_悩んでいたり、疑問を持つ夫婦\001_繊細な線画で描く葛藤する男女の静かな感情表現イラスト.png
# 画像を保存しました: c:\Users\athen\Desktop\works\adobestock\code\sketch_seed\output\2025-07-21T12-40_悩んでいたり、疑問を持つ夫婦\002_シンプルな色彩と線で綴る悩みを抱えるカップルの静かな時間.png
# c:\Users\athen\Desktop\works\adobestock\code\sketch_seed\output\2025-07-21T12-40_悩んでいたり、疑問を持つ夫婦\upscale フォルダを作成しました。
# アップスケール完了: c:\Users\athen\Desktop\works\adobestock\code\sketch_seed\output\2025-07-21T12-40_悩んでいたり、疑問を持つ夫婦\upscale\upscaled_000_2025-07-21T12-40.png
# ...

# %%
# gen.auto_gen_and_upscale(df_prompt)

# %%
KEYWORD = "一石二鳥"
KEYWORD = "「１つのアクションが２つの成果をもたらす」という概念"
TAGWORDS = ["一石二鳥", "効率", "効率化", "時間管理", "ビジネス", "戦略", "計画", "成功", "生産性", "社会人", "習い事", "習慣", "勉強", "投資"]


KEYWORD = "火に油を注ぐ"
TAGWORDS = ["火に油を注ぐ", "ことわざ", "感情", "対立", "idiom", "問題解決", "人間関係", "危機管理", "社会問題", "政治"]


KEYWORD = "青天の霹靂"
TAGWORDS = ["青天の霹靂", "ことわざ", "驚き", "予想外", "idiom", "ニュース", "事件", "社会", "自然", "天気"]

KEYWORD = "墓穴を掘る"
TAGWORDS = ["墓穴を掘る", "ことわざ", "自業自得", "失敗", "教訓", "idiom", "ビジネス", "人間関係", "戦略", "判断ミス"]

KEYWORD = "自分で自分の首を絞める"
TAGWORDS = ["自分で自分の首を絞める", "ことわざ", "自業自得", "失敗", "教訓", "idiom", "ビジネス", "人間関係", "戦略", "判断ミス"]

KEYWORD = "金をドブに捨てる"
TAGWORDS = ["金をドブに捨てる", "ことわざ", "無駄遣い", "節約", "経済", "idiom", "ビジネス", "投資", "消費", "教訓"]

KEYWORD = "類は友を呼ぶ"
TAGWORDS = ["類は友を呼ぶ", "ことわざ", "人間関係", "性格", "社会", "idiom", "心理学", "コミュニティ", "ビジネス", "ネットワーキング"]

KEYWORD = "捕らぬ狸の皮算用"
TAGWORDS = ["捕らぬ狸の皮算用", "ことわざ", "計画", "期待", "ビジネス", "idiom", "投資", "リスク管理", "教訓", "慎重さ"]
